# %%
# ?print # Get help about print function

#import pandas, numpy
import matplotlib as plt
import pandas as pd
import numpy as np
import seaborn as sns
import os

print(os.getcwd())
os.chdir('C:\\Users\\ewenxie\\OneDrive - Ericsson AB\\LearnAIML\\Python-Day2\\Data_part2a')
#os.chdir("C:\\xwy")
print(os.getcwd())

df_A = pd.read_csv("AAPL.csv")
df_A.head(4)
# Out:
# C:\xwy
# C:\Users\ewenxie\OneDrive - Ericsson AB\LearnAIML\Python-Day2\Data_part2a
#          Date        Open        High        Low       Close  Adj Close  \
# 0  2014-09-29  100.589996  100.690002  98.040001   99.620003  93.514290
# 1  2014-10-06   99.949997  102.379997  98.309998  100.730003  94.556244
# 2  2014-10-13  101.330002  101.779999  95.180000   97.669998  91.683792
# 3  2014-10-20   98.320000  105.489998  98.220001  105.220001  98.771042
#
#       Volume
# 0  142718700
# 1  280258200
# 2  358539800
# 3  358532900

# %%
str = 'abc'
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...
